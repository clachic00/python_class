# %%
# f = open('dev/frog_song.txt', 'w')

# %%
import os
# os.makedirs('C:/Users/Playdata/PYTHON/python_basic/17_File_IO/dev', exist_ok=True)

# %%
f = open('dev/frog_song.txt', 'r')
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[46], line 2
#       1 f = open('dev/frog_song.txt', 'r')
# ----> 2 print(f.read())
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xac in position 8: illegal multibyte sequence

# %%
f = open('dev/frog_song.txt', 'w', encoding="utf-8")
f.write("개구리 소년 빰빠바 개구리 소년 빰빠바\n\n네가 울면 무지개 연못에 비가 온단다\n비바람 몰아쳐도 이겨내고\n일곱번 넘어져도 일어나~라\n울지말고 일어나 피리를 불어라\n\n삘릴리 개굴개굴 삘릴리리\n삘릴리 개굴개굴 삘릴리리\n\n무지개 연못에 웃음꽃 핀다.\n")
f.close()

# %%
f = open('dev/frog_song.txt', 'r', encoding="utf-8")
print(f.read())
f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f1 = open('C:/Users/Playdata/PYTHON/python_basic/17_File_IO/dev/frog_song.txt', 'r', encoding="utf-8")
print(f1.read())
f1.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('dev/frog_song.txt', 'r', encoding="utf-8")

while True:
  line = f.readline()
  
  if not line:
    break
  print(line)
  
f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('dev/frog_song.txt', 'r', encoding="utf-8")

lines = f.readlines()
for line in lines:
    print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('dev/frog_song.txt', 'r', encoding="utf-8")

for line in f :
    print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f1 = open('dev/frog_song.txt', 'a', encoding="utf-8")
f1.write("노래 끝!")
f1.close()
f2 = open('dev/frog_song.txt', 'r', encoding="utf-8")
print(f2.read())
f2.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.
# 노래 끝!노래 끝!

# %%
with open("new/fi/le/newFile1.txt", "w", encoding="utf-8") as file1:
    file1.write("Life is too short, you need python")
file1.close()

# %%
with open("C:/Users/Playdata/PYTHON/python_basic/17_File_IO/new/fi/le/newFile2.txt", "w", encoding="utf-8") as file2:
    file2.write("Life is too short, you need python")
file2.close()
