# %%
print("""
세상에서 제일 긴 게 뭘가요?
기차? 기린의 목? 코끼리의 코?
전부 아닙니다.
여러분의 무난한 가능성입니다^^
"""

"""
이 함수는 나이를 반환하는 함수입니다.

입력값 : 문자열
출력값 : 숫자형
""")
# Out:
# 세상에서 제일 긴 게 뭘가요?
# 기차? 기린의 목? 코끼리의 코?
# 전부 아닙니다.
# 여러분의 무난한 가능성입니다^^
#
# 이 함수는 나이를 반환하는 함수입니다.
#
# 입력값 : 문자열
# 출력값 : 숫자형

# %%
greeting = "반갑습니"
name = "다람쥐"

print(greeting + name)
print(greeting + "다. "+ name + "입니다!")
# Out:
# 반갑습니다람쥐
# 반갑습니다. 다람쥐입니다!

# %%
name = "카피바라"
print(str(900)+"살 "+name+"입니다.")
# Out:
# 900살 카피바라입니다.

# %%
subject = "python"

print("무슨 일이든 시작 전에 세 번만 외쳐보자. "+ ("\n나는 " + subject + "을 잘할 수 있다!" )* 3 )
# Out:
# 무슨 일이든 시작 전에 세 번만 외쳐보자.
# 나는 python을 잘할 수 있다!
# 나는 python을 잘할 수 있다!
# 나는 python을 잘할 수 있다!

# %%
enrole_date = "2024/12/16"
rep_enrole_date = enrole_date.replace("/","-")
print(enrole_date)
print(rep_enrole_date)
# Out:
# 2024/12/16
# 2024-12-16

# %%
origin = "ohgiraffers"
with_white_space = '                                         oh giraffers   '

print(with_white_space.strip())
# Out:
# oh giraffers

# %%
with_white_space = '                                         oh giraffers   '
print(with_white_space)
print(with_white_space.strip(' o'))
print(origin.strip("os"))
origin = "sossosohgiraffers"

print(origin.lstrip("os"))
origin = "sossosohgiraffersoososoosos"

print(origin.rstrip("os"))
# Out:
#                                          oh giraffers
# h giraffers
# hgiraffer
# hgiraffers
# sossosohgiraffer

# %%
origin_str = "hELlo WoRlD"
print(origin_str.upper())
print(origin_str.lower())
print(origin_str.capitalize())
print(origin_str.swapcase())
print(origin_str.title())
# Out:
# HELLO WORLD
# hello world
# Hello world
# HelLO wOrLd
# Hello World

# %%
x = 10
y = "code"

print("x is %d" %x)
print("x is %s" %y)
# Out:
# x is 10
# x is code

# %%
x, y = 10, "code"
print("x is {0}".format(x))
print("y is {0}".format(y))
print("x is {new_x} and y is {new_y}".format(new_x=x,new_y=y))
# Out:
# x is 10
# y is code
# x is 10 and y is code

# %%
teacher_name = "카피바라"
print(f"안녕하세요. 오늘부터 여러분과 함께 공부할 {teacher_name} 강사입니다.")
# Out:
# 안녕하세요. 오늘부터 여러분과 함께 공부할 카피바라 강사입니다.

# %%
# 한줄 주석이다
 이렇게 그냥 작성하면 에러가 발생합니다.
 
print("이건 해석하구요")
#print("이건 해석하지 않습니다.")
# Out:
#   Cell In[189], line 2
#     이렇게 그냥 작성하면 에러가 발생합니다.
#     ^
# IndentationError: unexpected indent

# %%
"""
여러줄 주석입니다.
"""
# Out:
# '\n여러줄 주석입니다.\n'

# %%
print(True + 3)
print(3 + 0.5)
print(type(True + 3))
print(type(3 + 5.0))
# Out:
# 4
# 3.5
# <class 'int'>
# <class 'float'>

# %%
print(int('3')+4)
# Out:
# 7

# %%
print(float('3'))
print(type(float(3.0)))
# Out:
# 3.0
# <class 'float'>

# %%
print(str(1))
print(str(1.0))
print(str({1,2,3}))

print(type(str(1)))
print(type(str(1.0)))
print(type(str({1,2,3})))

print(list("ohgiraffers"))

print(list({1,2,3,4,5}))
# Out:
# 1
# 1.0
# {1, 2, 3}
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ['o', 'h', 'g', 'i', 'r', 'a', 'f', 'f', 'e', 'r', 's']
# [1, 2, 3, 4, 5]

# %%
print(
    list(
        {
        "1" : "사랑하는 우리반"
        ,"2" : "열심히 공부하십시오."
        ,"3" : "선생님 부탁입니다."
        }
     )
)
# Out:
# ['1', '2', '3']
