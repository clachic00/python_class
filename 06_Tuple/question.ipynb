# %% [markdown]
# ### **문제 6**
#
# 다음 조건에 맞게 **튜플**을 선언하고 활용하세요.
#
# 1. `my_tuple`이라는 이름으로 숫자 `10, 20, 30`을 가진 튜플을 선언하세요.
# 2. `my_tuple`의 두 번째 요소를 출력하세요.

# %%
my_tuple = 10, 20, 30
print(my_tuple[1])
# Out:
# 20
