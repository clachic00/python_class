# %%
num1 = 1
num2 = -1.1
print(type(num1))
print(type(num2))
print(type(123))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
num3 = 3.14
num4 = 1.0
print(type(num3))
print(type(num4))
# Out:
# <class 'float'>
# <class 'float'>

# %%
num5 = 3 + 4j
print(type(num5))
# Out:
# <class 'complex'>

# %%
# 정수 진법별 접두사
# 2진수(0,1) : 0b
# 8진수(0,7) : 0o
# 16진수(0,15) : 0x

a = 100
print(a)
b = 0o23
print(b)
c = 0xff
print(c)
# Out:
# 100
# 19
# 255

# %%
# 정수의 최대값
import sys
print(sys.maxsize)
# Out:
# 9223372036854775807

# %%
# 지수 표현식
# 4.24E10 = > 4.24*10^10
a = 4.24E15
b = 4.24E-4
print(a)
print(b)
print(type(a))
print(type(b))
# Out:
# 4240000000000000.0
# 0.000424
# <class 'float'>
# <class 'float'>

# %%
print(complex(1,1))
# Out:
# (1+1j)

# %%
num1 = 10
num2 = 3

print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
# Out:
# 13
# 7
# 30
# 3.3333333333333335

# %%
num3 = 10
num4 = 0.1
print(num3 + num4)
print(num3 - num4)
print(num3 * num4)
print(num3 / num4)
# Out:
# 10.1
# 9.9
# 1.0
# 100.0

# %%
num1 = 11
num2 = 7
print(num1 % num2)
# Out:
# 4

# %%
num1 = 11
num2 = 7
print(num1 // num2)
# Out:
# 1

# %%
num3 = 9
num4 = 2
num5 = 1/2
print(num3 ** num4)
print(num3 ** num5)
# Out:
# 81
# 3.0
