# %%
for x in [1, 2, 3]:
    
    print("앞", x)
    
    if x == 2:
        print("if", x)
        print("끝")  	
        break
    
    print("뒤", x)
# Out:
# 앞 1
# 뒤 1
# 앞 2
# if 2
# 끝

# %%
for i in range(3) :
    for j in range(3) :
        print (i, j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2
