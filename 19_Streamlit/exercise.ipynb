# %%
import streamlit as st

st.text("Hello, World")
# Out:
# 2025-12-01 15:18:43.902 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:18:44.021
# ...
#   command:
#
#     streamlit run c:\Users\Playdata\streamlit\streamlit_venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-12-01 15:18:44.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-01 15:18:44.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
