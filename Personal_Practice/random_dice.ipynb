# %%
import random
class Dice:
    def dice(dice_number):
        all_dice = []
        i=0
        for i in range(dice_number):
            dice = random.randint(1,6)
            all_dice.append(dice)
        print(all_dice);
dd = Dice

dice_num = input("던질 주사위의 갯수를 입력하세요")
dd.dice(int(dice_num))
# Out:
# [6]
