# %%
class Person:
    national = 'korea'
    
    def greeting(self):
        return 'Hello. This is Python'

# %%
class Person:
    national = 'korea'
    language = 'korean'
    
    def greeting(self):
        return '안녕하세요'
    
    def information(self):
        return "I'm from " + self.national + " and I use " + self.language
     
    def favorite(self, color):
        return "I love " + color

# %%
class Person:    
    national = 'korea'
    language = 'korean'
    
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def greeting(self):
        Person.information()
        return '안녕하세요'
    
    def information(self):
        return "I'm from " + self.national + " and I use " + self.language + ". My name is " + self.name + ". I'm " + str(self.age)
    
    def favorite(self, color):
        return "I love " + color

# %%
class Person :
    national = "korea"
    language = "korean"
    
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def greeting(self):
        return "안녕하세요"

# %%
# 전역변수
variable = "global variable"
print("전역", variable)

def outer_function():
    #외부 변수
    variable = "outer variable"
    print("지역 (외부 전역)", variable)
    
    def inner_function():    
        variable = "inner variable"
        print('지역(내부 함수)', variable)
        
    inner_function()
    
outer_function()
# Out:
# 전역 global variable
# 지역 (외부 전역) outer variable
# 지역(내부 함수) inner variable

# %%
class Character:
    
    def __init__(self, nickname, type):
        self.nickname = nickname
        self.__type = type
        
    def get_type(self):
        return self.__type
    def set_type(self, type):
        character_type = ['전사', '법사', '치유사']
        for given_type in character_type:
            if type == given_type :
                self.__type = type
                return
        raise ValueError("잘못된 캐릭터 타입을 선택하였습니다.")
my_character = Character("산골짜기다람쥐", "전사")
print(my_character.nickname)

try:
    print(my_character._Character__type)    # 이렇게 억지로 접근 가능
    print(my_character.__type)
except AttributeError as e:
    print(e)
    
# Private attribute에 접근하는 public method 사용
print(my_character.get_type())

# Public method를 통해 private attribute 수정
my_character.set_type("법사")
print(my_character.get_type())

# 잘못된 값으로 수정 시도
try:
    my_character.set_type("흑마법사") 
except ValueError as e:
    print(e)
# Out:
# 산골짜기다람쥐
# 전사
# 'Character' object has no attribute '__type'
# 전사
# 법사
# 잘못된 캐릭터 타입을 선택하였습니다.

# %%
class Person:    
    national = 'korea'
    language = 'korean'
    
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def greeting(self):
        return '안녕하세요'
    
    def information(self):
        return "I'm from " + self.national + " and I use " + self.language + ". My name is " + self.name + ". I'm " + str(self.age)
    
    def favorite(self, color):
        return "I love " + color
squirrel = Person("다람쥐", 900)
Gorilla = Person('고릴라', 20)

print(squirrel)
print(Gorilla)
print(squirrel.national)
print(squirrel.greeting())
print(Gorilla.information())
print(Gorilla.favorite('black'))
print(squirrel.information())
print(squirrel.favorite('white'))
# Out:
# <__main__.Person object at 0x00000211A81A3230>
# <__main__.Person object at 0x00000211A826F9D0>
# korea
# 안녕하세요
# I'm from korea and I use korean. My name is 고릴라. I'm 20
# I love black
# I'm from korea and I use korean. My name is 다람쥐. I'm 900
# I love white
