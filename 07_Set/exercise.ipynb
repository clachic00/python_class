# %%
safari_set = {"Bear", "Koala", "Gorilla", "Squirrel"}

numbers = {1, 2, 3, 4, 5}

mixed_set = {1, "Bear", (1,2,3)}
mixed_list = list(mixed_set)

print(mixed_list[1][1])
# Out:
# 2

# %%
safari_set = {"Bear", "Koala", "Gorilla", "Squirrel"}
safari_set.remove("Bear")
safari_set.add("Lion")
print(safari_set)
# Out:
# {'Koala', 'Lion', 'Gorilla', 'Squirrel'}

# %%
safari_set = {"Bear", "Koala", "Gorilla", "Squirrel"}
safari_set.discard("Bear")
safari_set.add("Lion")
print(safari_set)
# Out:
# {'Koala', 'Lion', 'Gorilla', 'Squirrel'}

# %%
ohgiraffers = {1, "Squirrel", 2, 'Bear', 3.0, 'pig', tuple({'Gorilla'}), True}
print(ohgiraffers)
# Out:
# {1, 2, 3.0, 'pig', ('Gorilla',), 'Bear', 'Squirrel'}

# %%
javaTeam = {'Squirrel','Gorilla', 'Tiger', 'Sheep', 'monkey', 'wolf'}
print('Gorilla' in javaTeam)    # BOOLEAN
# Out:
# True

# %%
ohgiraffers = set(["Monkey", "Tiger", "Wolf"])
print(ohgiraffers)    # {'Tiger', 'Monkey', 'Wolf'}

ohgiraffers.update(["D", "F", "G", "H"])
print(ohgiraffers)    # {'Tiger', 'Squirrel', 'Monkey', 'Wolf'}
# Out:
# {'Wolf', 'Monkey', 'Tiger'}
# {'D', 'H', 'Wolf', 'G', 'F', 'Monkey', 'Tiger'}

# %%
ohgiraffers = set(["Monkey", "Tiger", "Wolf"])
print(ohgiraffers.pop())    # {'Tiger', 'Monkey', 'Wolf'}
print(ohgiraffers)
# Out:
# Wolf
# {'Monkey', 'Tiger'}

# %%
ohgiraffers = set(["Monkey", "Tiger", "Wolf"])
print(ohgiraffers.clear())    # {'Tiger', 'Monkey', 'Wolf'}
print(ohgiraffers)
# Out:
# None
# set()

# %%
javaTeam = {'Squirrel','Gorilla', 'Tiger', 'Sheep', 'monkey', 'wolf'}
pythonTeam = {'Pig', 'Squirrel', 'Bear', 'Gorilla'}

print("[합집합]")
print(javaTeam.union(pythonTeam))
print(javaTeam | pythonTeam)

print("[교집합]")
print(javaTeam.intersection(pythonTeam))
print(javaTeam & pythonTeam)

print("[차집합]")
print(javaTeam.difference(pythonTeam))
print(javaTeam - pythonTeam)

print("[대칭 차집합]")
print(javaTeam.symmetric_difference(pythonTeam))
print(javaTeam ^ pythonTeam)
# Out:
# [합집합]
# {'monkey', 'wolf', 'Pig', 'Sheep', 'Bear', 'Gorilla', 'Squirrel', 'Tiger'}
# {'monkey', 'wolf', 'Pig', 'Sheep', 'Bear', 'Gorilla', 'Squirrel', 'Tiger'}
# [교집합]
# {'Squirrel', 'Gorilla'}
# {'Squirrel', 'Gorilla'}
# [차집합]
# {'monkey', 'Sheep', 'wolf', 'Tiger'}
# {'monkey', 'Sheep', 'wolf', 'Tiger'}
# [대칭 차집합]
# {'monkey', 'wolf', 'Pig', 'Sheep', 'Bear', 'Tiger'}
# {'monkey', 'wolf', 'Pig', 'Sheep', 'Bear', 'Tiger'}

# %%
ohgiraffers = {'Squirrel','Gorilla', 'Tiger', 'Sheep', 'monkey', 'wolf'}
zzap_ohgiraffers = ohgiraffers.copy()
print(ohgiraffers)         # {'wolf', 'Sheep', 'Tiger', 'Gorilla', 'monkey', 'Squirrel'}
print(zzap_ohgiraffers)    # {'wolf', 'Sheep', 'Tiger', 'Gorilla', 'monkey', 'Squirrel'}

zzap_ohgiraffers.remove('Tiger')
print(ohgiraffers)         # {'wolf', 'Sheep', 'Tiger', 'Gorilla', 'monkey', 'Squirrel'}
print(zzap_ohgiraffers)    # {'wolf', 'Sheep', 'Gorilla', 'monkey', 'Squirrel'}
# Out:
# {'monkey', 'Sheep', 'wolf', 'Gorilla', 'Squirrel', 'Tiger'}
# {'monkey', 'Sheep', 'wolf', 'Gorilla', 'Squirrel', 'Tiger'}
# {'monkey', 'Sheep', 'wolf', 'Gorilla', 'Squirrel', 'Tiger'}
# {'monkey', 'Sheep', 'wolf', 'Gorilla', 'Squirrel'}
