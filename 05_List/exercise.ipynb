# %%
fruits = ['Apple', 'Banana', 'Coconut', 'Durian', 'Elderberry']
print(fruits)
# Out:
# ['Apple', 'Banana', 'Coconut', 'Durian', 'Elderberry']

# %%
rainbow_split = "빨-주-노-초-파-남-보"
splited_rainbow = rainbow_split.split("-")
print(splited_rainbow)
print(*splited_rainbow)
# Out:
# ['빨', '주', '노', '초', '파', '남', '보']
# 빨 주 노 초 파 남 보

# %%
list1 = []
list2 = list()
list3 = list('hello')
list4 = list('hello'+'hi')
print(list3)
print(list4)
# Out:
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'e', 'l', 'l', 'o', 'h', 'i']

# %%
safari_list = ["Bear", "Koala", "Lion", "Squirrel"]
another_safari_list = ["Monkey","Tiger","Wolf"]
print(safari_list+another_safari_list)
# Out:
# ['Bear', 'Koala', 'Lion', 'Squirrel', 'Monkey', 'Tiger', 'Wolf']

# %%
safari_list = ["Bear", "Koala", "Lion", "Squirrel"]
result = safari_list * 4
print(result)
# Out:
# ['Bear', 'Koala', 'Lion', 'Squirrel', 'Bear', 'Koala', 'Lion', 'Squirrel', 'Bear', 'Koala', 'Lion', 'Squirrel', 'Bear', 'Koala', 'Lion', 'Squirrel']

# %%
fruits = ["Apple", "Banana", "Coconut", "Durian", "Elderberry", "Apple"]
print("Apple : ", fruits.count("Apple"))
print("test : ", fruits.count("test"))
# Out:
# Apple :  2
# test :  0

# %%
print("index : ", fruits.index("Apple"))
print("index : ", fruits.index("Coconut"))
print("index : ", fruits.index("Apple",3))
# Out:
# index :  0
# index :  2
# index :  5

# %%
# 원본 비보존
print(fruits.reverse())
print(fruits)
# Out:
# None
# ['Apple', 'Elderberry', 'Durian', 'Coconut', 'Banana', 'Apple']

# %%
# 원본 보존
fruits = ["Apple", "Banana", "Coconut", "Durian", "Elderberry", "Apple"]
reversed_fruits = reversed(fruits)
print(fruits)
print(reversed_fruits)
print(list(reversed_fruits))
# Out:
# ['Apple', 'Banana', 'Coconut', 'Durian', 'Elderberry', 'Apple']
# ...
# ['Apple', 'Elderberry', 'Durian', 'Coconut', 'Banana', 'Apple']

# %%
fruits = ["Apple", "Banana", "Coconut", "Durian", "Elderberry", "Apple"]
fruits.append("pineapple")
print(fruits)
# Out:
# ['Apple', 'Banana', 'Coconut', 'Durian', 'Elderberry', 'Apple', 'pineapple']

# %%
fruits = ["Apple", "Banana", "Coconut", "Durian", "Elderberry", "Apple"]
fruits.insert(0,'Monkey Banana')
print(fruits)
# Out:
# ['Monkey Banana', 'Apple', 'Banana', 'Coconut', 'Durian', 'Elderberry', 'Apple']

# %%
fruits = ["Apple", "Banana", "Coconut", "Durian", "Elderberry", "Apple"]
fruits.sort()
print(fruits)
# Out:
# ['Apple', 'Apple', 'Banana', 'Coconut', 'Durian', 'Elderberry']

# %%
fruits = ["Apple", "Banana", "Coconut", "Durian", "Elderberry", "Apple"]
fruits.sort(key=len)
print(fruits)

# %%
fruits = ["Apple", "Banana", "Coconut", "Durian", "Elderberry", "Apple"]
fruits.sort(key=lambda x:(len(x),x))
print(fruits)
# Out:
# ['Apple', 'Apple', 'Banana', 'Durian', 'Coconut', 'Elderberry']

# %%
fruits = ["Apple", "Banana", "Coconut", "Durian", "Elderberry", "Apple"]
sorted_fruits = sorted(fruits)
print(fruits)
print(sorted_fruits)
# Out:
# ['Apple', 'Banana', 'Coconut', 'Durian', 'Elderberry', 'Apple']
# ['Apple', 'Apple', 'Banana', 'Coconut', 'Durian', 'Elderberry']

# %%
fruits = ["Apple", "Banana", "Coconut", "Durian", "Elderberry", "Apple"]
temp = fruits.remove("Apple")
print(temp)
print(fruits)
# Out:
# None
# ['Banana', 'Coconut', 'Durian', 'Elderberry', 'Apple']

# %%
fruits = ["Apple", "Banana", "Coconut", "Durian", "Elderberry"]
temp = fruits.pop()
print(temp)
print(fruits)
# Out:
# Elderberry
# ['Apple', 'Banana', 'Coconut', 'Durian']

# %%
plates = ['plate1', 'plate2']
plates.append('plate3') 
plates.append('plate4')
print(plates)
# Out:
# ['plate1', 'plate2', 'plate3', 'plate4']

# %%
print(plates.pop())
print(plates)
print(plates.pop())
print(plates.pop())
print(plates)
# Out:
# plate1
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[202], line 3
#       1 print(plates.pop())
#       2 print(plates)
# ----> 3 print(plates.pop())
#       4 print(plates.pop())
#       5 print(plates)
#
# IndexError: pop from empty list

# %%
abclist = ['A', 'B', 'C', 'D', 'E', 'F']
print(abclist)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
abclist = ['A', 'B', 'C', 'D', 'E', 'F']
del abclist[0]
print(abclist)
# Out:
# ['B', 'C', 'D', 'E', 'F']

# %%
abclist = ['A', 'B', 'C', 'D', 'E', 'F']
del abclist[1:3]
print(abclist)
# Out:
# ['A', 'D', 'E', 'F']

# %%
abclist = ['A', 'B', 'C', 'D', 'E', 'F']
del abclist[:2]
print(abclist)
# Out:
# ['C', 'D', 'E', 'F']

# %%
abclist = ['A', 'B', 'C', 'D', 'E', 'F']
del abclist[:]
print(abclist)
# Out:
# []

# %%
abclist = ['A', 'B', 'C', 'D', 'E', 'F']
del abclist[0:2]
print(abclist)
# Out:
# ['C', 'D', 'E', 'F']

# %%
abclist = ['A', 'B', 'C', 'D', 'E', 'F']
del abclist
print(abclist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[219], line 3
#       1 abclist = ['A', 'B', 'C', 'D', 'E', 'F']
#       2 del abclist
# ----> 3 print(abclist)
#
# NameError: name 'abclist' is not defined

# %%
from collections import deque
dq = deque()
dq.append("a")
dq.append("b")
dq.append("c")

print(dq)

left_value = dq.popleft()
print(left_value)
print(dq)

value = dq.pop()
print(value)
print(dq)
# Out:
# deque(['a', 'b', 'c'])
# a
# deque(['b', 'c'])
# c
# deque(['b'])

# %%
ls = [p**2 for p in range(1,11)  ]
print(ls)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
