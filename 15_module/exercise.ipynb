# %%
import lion_module

print(lion_module.lion)
print(lion_module.gorrilla())
print(lion_module.pig())
print(lion_module.tiger())

# %%
from lion_module import lion, gorrilla

print(lion_module.lion)
print(lion_module.gorrilla())
print(lion_module.pig())
print(lion_module.tiger())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from lion_module import lion, gorrilla
# ----> 3 print(lion_module.lion)
#       4 print(lion_module.gorrilla())
#       5 print(lion_module.pig())
#
# NameError: name 'lion_module' is not defined

# %%
import lion_module as Lm 
print(Lm.gorrilla())
print(Lm.pig())
print(Lm.tiger())
print(Lm.lion)
# Out:
# 크왕
# 꿀꿀
# 어흥
# 사자

# %%
from lion_module import lion as l , gorrilla as g 
print(l)
print(g())
# Out:
# 사자
# 크왕

# %%
import math
print(math.sqrt(16))
print(math.factorial(5))
print(math.pi)
# Out:
# 4.0
# 120
# 3.141592653589793

# %%
import sys
import os

# sys.path.append(os.path.dirname(os.path.dirname(__file__)))
